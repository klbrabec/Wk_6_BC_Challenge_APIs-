# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
import random
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
#lat creation
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
#lng creation
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations

#merge lats/lngs into a single set 
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
#check coordinates table for accuracy (uncomment to see list) 
#coordinates

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
city_list = [] 

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in city_list:
       city_list.append(city)

# Print the city count to confirm sufficient count
len(city_list)
# Out:
# 747

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print URL to validate (uncomment to execute)
#print(url)

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(city_list):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        #convert date to ISO standard 
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lulea
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | hofn
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | roald
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | carutapera
# Processing Record 10 of Set 1 | la ronge
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | saskylakh
# Processing Record 13 of Set 1 | boyolangu
# Processing Record 14 of Set 1 | cabo san lucas
# Processing Record 15 of Set 1 | antofagasta
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 1 | kodiak
# Processing Record 19 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 1 | perdika
# Processing Record 21 of Set 1 | broome
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | vanimo
# Processing Record 24 of Set 1 | montanha
# Processing Record 25 of Set 1 | doha
# Processing Record 26 of Set 1 | shenjiamen
# Processing Record 27 of Set 1 | verkhnyaya inta
# Processing Record 28 of Set 1 | qaanaaq
# Processing Record 29 of Set 1 | arraial do cabo
# Processing Record 30 of Set 1 | barrow
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 1 | nizhneivkino
# Processing Record 34 of Set 1 | hermanus
# Processing Record 35 of Set 1 | iqaluit
# Processing Record 36 of Set 1 | saint george
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | guerrero negro
# Processing Record 39 of Set 1 | butaritari
# Processing Record 40 of Set 1 | vestmanna
# Processing Record 41 of Set 1 | mataura
# Processing Record 42 of Set 1 | beloha
# Processing Record 43 of Set 1 | new norfolk
# Processing Record 44 of Set 1 | okhotsk
# Processing Record 45 of Set 1 | ribeira grande
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | medina del campo
# Processing Record 48 of Set 1 | busselton
# Processing Record 49 of Set 1 | bocana de paiwas
# Processing Record 50 of Set 1 | parrita
# Processing Record 1 of Set 2 | mahebourg
# Processing Record 2 of Set 2 | port elizabeth
# Processing Record 3 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 4 of Set 2 | payson
# Processing Record 5 of Set 2 | tabou
# Processing Record 6 of Set 2 | grindavik
# Processing Record 7 of Set 2 | hambantota
# Processing Record 8 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 9 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 2 | carnarvon
# Processing Record 11 of Set 2 | vaini
# Processing Record 12 of Set 2 | stekolnyy
# City not found. Skipping...
# Processing Record 13 of Set 2 | brattvag
# Processing Record 14 of Set 2 | lerwick
# Processing Record 15 of Set 2 | northam
# Processing Record 16 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 2 | pisco
# Processing Record 18 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 2 | turba
# Processing Record 20 of Set 2 | tuktoyaktuk
# Processing Record 21 of Set 2 | kavaratti
# Processing Record 22 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 2 | muravlenko
# Processing Record 24 of Set 2 | te anau
# Processing Record 25 of Set 2 | paamiut
# Processing Record 26 of Set 2 | praia
# Processing Record 27 of Set 2 | caceres
# Processing Record 28 of Set 2 | caravelas
# Processing Record 29 of Set 2 | avarua
# Processing Record 30 of Set 2 | tiksi
# Processing Record 31 of Set 2 | hasaki
# Processing Record 32 of Set 2 | talnakh
# Processing Record 33 of Set 2 | owerri
# Processing Record 34 of Set 2 | tuatapere
# Processing Record 35 of Set 2 | grinnell
# Processing Record 36 of Set 2 | nemuro
# Processing Record 37 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 2 | yerbogachen
# Processing Record 39 of Set 2 | manavalakurichi
# Processing Record 40 of Set 2 | necochea
# Processing Record 41 of Set 2 | rio gallegos
# Processing Record 42 of Set 2 | airai
# Processing Record 43 of Set 2 | lavrentiya
# Processing Record 44 of Set 2 | pacific grove
# Processing Record 45 of Set 2 | ballina
# Processing Record 46 of Set 2 | vila velha
# Processing Record 47 of Set 2 | marmaron
# City not found. Skipping...
# Processing Record 48 of Set 2 | oxford
# Processing Record 49 of Set 2 | oxapampa
# Processing Record 50 of Set 2 | gravdal
# Processing Record 1 of Set 3 | touros
# Processing Record 2 of Set 3 | pestravka
# Processing Record 3 of Set 3 | port alfred
# Processing Record 4 of Set 3 | arawa
# Processing Record 5 of Set 3 | sept-iles
# Processing Record 6 of Set 3 | labuhan
# Processing Record 7 of Set 3 | pop
# Processing Record 8 of Set 3 | port macquarie
# Processing Record 9 of Set 3 | milazzo
# Processing Record 10 of Set 3 | kenai
# Processing Record 11 of Set 3 | kavieng
# Processing Record 12 of Set 3 | manakara
# Processing Record 13 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 3 | fuerte olimpo
# Processing Record 15 of Set 3 | dabou
# Processing Record 16 of Set 3 | sinjar
# Processing Record 17 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 3 | yurginskoye
# Processing Record 19 of Set 3 | takoradi
# Processing Record 20 of Set 3 | okha
# Processing Record 21 of Set 3 | thompson
# Processing Record 22 of Set 3 | saldanha
# Processing Record 23 of Set 3 | bredasdorp
# Processing Record 24 of Set 3 | bethel
# Processing Record 25 of Set 3 | westport
# Processing Record 26 of Set 3 | hithadhoo
# Processing Record 27 of Set 3 | faya
# Processing Record 28 of Set 3 | mayumba
# Processing Record 29 of Set 3 | rupert
# Processing Record 30 of Set 3 | avera
# Processing Record 31 of Set 3 | beidao
# Processing Record 32 of Set 3 | liwale
# Processing Record 33 of Set 3 | castro
# Processing Record 34 of Set 3 | ajdabiya
# Processing Record 35 of Set 3 | lima
# Processing Record 36 of Set 3 | isangel
# Processing Record 37 of Set 3 | coahuayana
# Processing Record 38 of Set 3 | miri
# Processing Record 39 of Set 3 | lebu
# Processing Record 40 of Set 3 | narsaq
# Processing Record 41 of Set 3 | chumikan
# Processing Record 42 of Set 3 | aksu
# Processing Record 43 of Set 3 | salalah
# Processing Record 44 of Set 3 | saint-philippe
# Processing Record 45 of Set 3 | formoso do araguaia
# City not found. Skipping...
# Processing Record 46 of Set 3 | ancud
# Processing Record 47 of Set 3 | namibe
# Processing Record 48 of Set 3 | sungairaya
# Processing Record 49 of Set 3 | ahuimanu
# Processing Record 50 of Set 3 | de-kastri
# Processing Record 1 of Set 4 | atasu
# Processing Record 2 of Set 4 | kiruna
# Processing Record 3 of Set 4 | boa viagem
# Processing Record 4 of Set 4 | nantucket
# Processing Record 5 of Set 4 | havre-saint-pierre
# Processing Record 6 of Set 4 | tura
# Processing Record 7 of Set 4 | jackson
# Processing Record 8 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 9 of Set 4 | cururupu
# Processing Record 10 of Set 4 | ponta do sol
# Processing Record 11 of Set 4 | hilo
# Processing Record 12 of Set 4 | qasigiannguit
# Processing Record 13 of Set 4 | fiumicino
# Processing Record 14 of Set 4 | autazes
# Processing Record 15 of Set 4 | richard toll
# City not found. Skipping...
# Processing Record 16 of Set 4 | severo-kurilsk
# Processing Record 17 of Set 4 | kendari
# Processing Record 18 of Set 4 | margate
# Processing Record 19 of Set 4 | yulara
# Processing Record 20 of Set 4 | berdyuzhye
# City not found. Skipping...
# Processing Record 21 of Set 4 | dikson
# Processing Record 22 of Set 4 | flinders
# Processing Record 23 of Set 4 | sao filipe
# Processing Record 24 of Set 4 | sheltozero
# Processing Record 25 of Set 4 | cape town
# Processing Record 26 of Set 4 | krasnorechenskiy
# Processing Record 27 of Set 4 | waitati
# Processing Record 28 of Set 4 | norman wells
# Processing Record 29 of Set 4 | andevoranto
# City not found. Skipping...
# Processing Record 30 of Set 4 | port blair
# Processing Record 31 of Set 4 | lata
# Processing Record 32 of Set 4 | puerto ayora
# Processing Record 33 of Set 4 | mildura
# Processing Record 34 of Set 4 | cherskiy
# Processing Record 35 of Set 4 | georgetown
# Processing Record 36 of Set 4 | zaanstad
# Processing Record 37 of Set 4 | ilulissat
# Processing Record 38 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 39 of Set 4 | poum
# Processing Record 40 of Set 4 | nelson bay
# Processing Record 41 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 4 | dhidhdhoo
# Processing Record 43 of Set 4 | dakar
# Processing Record 44 of Set 4 | havoysund
# Processing Record 45 of Set 4 | beringovskiy
# Processing Record 46 of Set 4 | tasiilaq
# Processing Record 47 of Set 4 | rodino
# Processing Record 48 of Set 4 | khatanga
# Processing Record 49 of Set 4 | alofi
# Processing Record 50 of Set 4 | kahului
# Processing Record 1 of Set 5 | luderitz
# Processing Record 2 of Set 5 | macau
# Processing Record 3 of Set 5 | chokurdakh
# Processing Record 4 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 5 | hovd
# Processing Record 6 of Set 5 | imeni poliny osipenko
# Processing Record 7 of Set 5 | korla
# Processing Record 8 of Set 5 | aasiaat
# Processing Record 9 of Set 5 | puerto quijarro
# Processing Record 10 of Set 5 | digha
# Processing Record 11 of Set 5 | ust-ilimsk
# Processing Record 12 of Set 5 | lorengau
# Processing Record 13 of Set 5 | teseney
# Processing Record 14 of Set 5 | elat
# Processing Record 15 of Set 5 | east london
# Processing Record 16 of Set 5 | adrar
# Processing Record 17 of Set 5 | rio grande
# Processing Record 18 of Set 5 | marsaxlokk
# Processing Record 19 of Set 5 | buin
# Processing Record 20 of Set 5 | moulins
# Processing Record 21 of Set 5 | kaili
# Processing Record 22 of Set 5 | sobolevo
# Processing Record 23 of Set 5 | mar del plata
# Processing Record 24 of Set 5 | balykshi
# Processing Record 25 of Set 5 | komsomolskiy
# Processing Record 26 of Set 5 | amuntai
# Processing Record 27 of Set 5 | mwaya
# Processing Record 28 of Set 5 | astipalaia
# City not found. Skipping...
# Processing Record 29 of Set 5 | izmayil
# Processing Record 30 of Set 5 | orocue
# Processing Record 31 of Set 5 | victoria
# Processing Record 32 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 33 of Set 5 | tibati
# Processing Record 34 of Set 5 | tenenkou
# Processing Record 35 of Set 5 | taonan
# Processing Record 36 of Set 5 | clyde river
# Processing Record 37 of Set 5 | chuy
# Processing Record 38 of Set 5 | bambous virieux
# Processing Record 39 of Set 5 | upernavik
# Processing Record 40 of Set 5 | belawan
# Processing Record 41 of Set 5 | beian
# Processing Record 42 of Set 5 | evinayong
# Processing Record 43 of Set 5 | las vegas
# Processing Record 44 of Set 5 | torbay
# Processing Record 45 of Set 5 | calama
# Processing Record 46 of Set 5 | vila franca do campo
# Processing Record 47 of Set 5 | kapit
# Processing Record 48 of Set 5 | pottstown
# Processing Record 49 of Set 5 | longyearbyen
# Processing Record 50 of Set 5 | fare
# Processing Record 1 of Set 6 | acton vale
# Processing Record 2 of Set 6 | laguna
# Processing Record 3 of Set 6 | mount isa
# Processing Record 4 of Set 6 | samarai
# Processing Record 5 of Set 6 | bend
# Processing Record 6 of Set 6 | san marcos
# Processing Record 7 of Set 6 | vestmannaeyjar
# Processing Record 8 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 6 | taltal
# Processing Record 10 of Set 6 | macapa
# Processing Record 11 of Set 6 | faanui
# Processing Record 12 of Set 6 | lensk
# Processing Record 13 of Set 6 | katangli
# Processing Record 14 of Set 6 | jieshi
# Processing Record 15 of Set 6 | provideniya
# Processing Record 16 of Set 6 | fort-shevchenko
# Processing Record 17 of Set 6 | wattegama
# Processing Record 18 of Set 6 | venado
# Processing Record 19 of Set 6 | eyl
# Processing Record 20 of Set 6 | bubaque
# Processing Record 21 of Set 6 | espinosa
# Processing Record 22 of Set 6 | pahrump
# Processing Record 23 of Set 6 | yenagoa
# Processing Record 24 of Set 6 | bandarbeyla
# Processing Record 25 of Set 6 | areosa
# Processing Record 26 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 27 of Set 6 | cockburn town
# Processing Record 28 of Set 6 | barabai
# Processing Record 29 of Set 6 | gamba
# Processing Record 30 of Set 6 | sumedang
# Processing Record 31 of Set 6 | harsin
# Processing Record 32 of Set 6 | mehamn
# Processing Record 33 of Set 6 | maniitsoq
# Processing Record 34 of Set 6 | shenxian
# Processing Record 35 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 36 of Set 6 | logan lake
# Processing Record 37 of Set 6 | coquimbo
# Processing Record 38 of Set 6 | maceio
# Processing Record 39 of Set 6 | charters towers
# Processing Record 40 of Set 6 | khandyga
# Processing Record 41 of Set 6 | wiang sa
# Processing Record 42 of Set 6 | la orilla
# Processing Record 43 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 44 of Set 6 | troitsk
# Processing Record 45 of Set 6 | san patricio
# Processing Record 46 of Set 6 | akodia
# Processing Record 47 of Set 6 | atar
# Processing Record 48 of Set 6 | zhangjiakou
# Processing Record 49 of Set 6 | fortuna
# Processing Record 50 of Set 6 | denpasar
# Processing Record 1 of Set 7 | evensk
# Processing Record 2 of Set 7 | long beach
# Processing Record 3 of Set 7 | menongue
# Processing Record 4 of Set 7 | sambava
# Processing Record 5 of Set 7 | belaya gora
# Processing Record 6 of Set 7 | khandbari
# Processing Record 7 of Set 7 | san cristobal
# Processing Record 8 of Set 7 | mitsamiouli
# Processing Record 9 of Set 7 | bilma
# Processing Record 10 of Set 7 | north bend
# Processing Record 11 of Set 7 | ostrovnoy
# Processing Record 12 of Set 7 | tygda
# Processing Record 13 of Set 7 | ayan
# Processing Record 14 of Set 7 | pevek
# Processing Record 15 of Set 7 | erzin
# Processing Record 16 of Set 7 | dryden
# Processing Record 17 of Set 7 | moses lake
# Processing Record 18 of Set 7 | port-cartier
# Processing Record 19 of Set 7 | coihaique
# Processing Record 20 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 7 | codajas
# Processing Record 22 of Set 7 | jeremie
# Processing Record 23 of Set 7 | london
# Processing Record 24 of Set 7 | half moon bay
# Processing Record 25 of Set 7 | mulanje
# Processing Record 26 of Set 7 | mecca
# Processing Record 27 of Set 7 | lagoa
# Processing Record 28 of Set 7 | dawei
# Processing Record 29 of Set 7 | antalaha
# Processing Record 30 of Set 7 | saint-pierre
# Processing Record 31 of Set 7 | inhambane
# Processing Record 32 of Set 7 | sola
# Processing Record 33 of Set 7 | tagusao
# Processing Record 34 of Set 7 | lompoc
# Processing Record 35 of Set 7 | camacha
# Processing Record 36 of Set 7 | sines
# Processing Record 37 of Set 7 | troina
# Processing Record 38 of Set 7 | plettenberg bay
# Processing Record 39 of Set 7 | los llanos de aridane
# Processing Record 40 of Set 7 | haines junction
# Processing Record 41 of Set 7 | goderich
# Processing Record 42 of Set 7 | akyab
# Processing Record 43 of Set 7 | bathsheba
# Processing Record 44 of Set 7 | ilo
# Processing Record 45 of Set 7 | raudeberg
# Processing Record 46 of Set 7 | kollumerland
# City not found. Skipping...
# Processing Record 47 of Set 7 | dingle
# Processing Record 48 of Set 7 | merauke
# Processing Record 49 of Set 7 | nikolskoye
# Processing Record 50 of Set 7 | aklavik
# Processing Record 1 of Set 8 | bengkulu
# Processing Record 2 of Set 8 | tlahualilo
# City not found. Skipping...
# Processing Record 3 of Set 8 | rock sound
# Processing Record 4 of Set 8 | souillac
# Processing Record 5 of Set 8 | bujaru
# Processing Record 6 of Set 8 | saint anthony
# Processing Record 7 of Set 8 | acapulco
# Processing Record 8 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 8 | pozo colorado
# Processing Record 10 of Set 8 | rio de jesus
# Processing Record 11 of Set 8 | waspan
# Processing Record 12 of Set 8 | zachary
# Processing Record 13 of Set 8 | zhezkazgan
# Processing Record 14 of Set 8 | bowen
# Processing Record 15 of Set 8 | viedma
# Processing Record 16 of Set 8 | maumere
# Processing Record 17 of Set 8 | sorochinsk
# Processing Record 18 of Set 8 | kielce
# Processing Record 19 of Set 8 | tabarqah
# City not found. Skipping...
# Processing Record 20 of Set 8 | esperance
# Processing Record 21 of Set 8 | hearst
# Processing Record 22 of Set 8 | biggar
# Processing Record 23 of Set 8 | ocampo
# Processing Record 24 of Set 8 | reyes
# Processing Record 25 of Set 8 | zeya
# Processing Record 26 of Set 8 | waingapu
# Processing Record 27 of Set 8 | amboise
# Processing Record 28 of Set 8 | nouadhibou
# Processing Record 29 of Set 8 | husavik
# Processing Record 30 of Set 8 | svetlogorsk
# Processing Record 31 of Set 8 | moroni
# Processing Record 32 of Set 8 | kurchum
# Processing Record 33 of Set 8 | west plains
# Processing Record 34 of Set 8 | buala
# Processing Record 35 of Set 8 | curaca
# Processing Record 36 of Set 8 | hami
# Processing Record 37 of Set 8 | phalombe
# Processing Record 38 of Set 8 | carolina
# Processing Record 39 of Set 8 | sawtell
# Processing Record 40 of Set 8 | jamsa
# Processing Record 41 of Set 8 | egvekinot
# Processing Record 42 of Set 8 | wuan
# Processing Record 43 of Set 8 | bulungu
# Processing Record 44 of Set 8 | vila praia de ancora
# Processing Record 45 of Set 8 | sal rei
# Processing Record 46 of Set 8 | sibolga
# Processing Record 47 of Set 8 | naze
# Processing Record 48 of Set 8 | mtwara
# Processing Record 49 of Set 8 | fairbanks
# Processing Record 50 of Set 8 | ambon
# Processing Record 1 of Set 9 | vaitape
# Processing Record 2 of Set 9 | gat
# Processing Record 3 of Set 9 | aksarka
# Processing Record 4 of Set 9 | kilindoni
# Processing Record 5 of Set 9 | comodoro rivadavia
# Processing Record 6 of Set 9 | souris
# Processing Record 7 of Set 9 | eresos
# Processing Record 8 of Set 9 | vila
# Processing Record 9 of Set 9 | micheweni
# Processing Record 10 of Set 9 | zheleznodorozhnyy
# Processing Record 11 of Set 9 | meulaboh
# Processing Record 12 of Set 9 | kruisfontein
# Processing Record 13 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 14 of Set 9 | ekibastuz
# Processing Record 15 of Set 9 | ranong
# Processing Record 16 of Set 9 | harbour breton
# Processing Record 17 of Set 9 | misratah
# Processing Record 18 of Set 9 | peachland
# Processing Record 19 of Set 9 | takab
# Processing Record 20 of Set 9 | ust-kuyga
# Processing Record 21 of Set 9 | matamoros
# Processing Record 22 of Set 9 | hohhot
# Processing Record 23 of Set 9 | college
# Processing Record 24 of Set 9 | belmonte
# Processing Record 25 of Set 9 | miguel auza
# Processing Record 26 of Set 9 | kibaya
# Processing Record 27 of Set 9 | nanortalik
# Processing Record 28 of Set 9 | sungaipenuh
# Processing Record 29 of Set 9 | birjand
# Processing Record 30 of Set 9 | tumut
# Processing Record 31 of Set 9 | hervey bay
# Processing Record 32 of Set 9 | sisimiut
# Processing Record 33 of Set 9 | astana
# Processing Record 34 of Set 9 | adeje
# Processing Record 35 of Set 9 | khani
# Processing Record 36 of Set 9 | darhan
# Processing Record 37 of Set 9 | oistins
# Processing Record 38 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 9 | alekseyevsk
# Processing Record 40 of Set 9 | phayakkhaphum phisai
# Processing Record 41 of Set 9 | pedernales
# Processing Record 42 of Set 9 | ventspils
# Processing Record 43 of Set 9 | coos bay
# Processing Record 44 of Set 9 | bacuit
# City not found. Skipping...
# Processing Record 45 of Set 9 | katsuura
# Processing Record 46 of Set 9 | katobu
# Processing Record 47 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 9 | puerto madryn
# Processing Record 49 of Set 9 | suao
# City not found. Skipping...
# Processing Record 50 of Set 9 | edd
# Processing Record 1 of Set 10 | kirakira
# Processing Record 2 of Set 10 | pacifica
# Processing Record 3 of Set 10 | villa carlos paz
# Processing Record 4 of Set 10 | cap-aux-meules
# Processing Record 5 of Set 10 | bato
# Processing Record 6 of Set 10 | baft
# Processing Record 7 of Set 10 | guajara-mirim
# City not found. Skipping...
# Processing Record 8 of Set 10 | kaitangata
# Processing Record 9 of Set 10 | polyarnyy
# Processing Record 10 of Set 10 | eldorado
# Processing Record 11 of Set 10 | kyzyl-suu
# Processing Record 12 of Set 10 | batagay-alyta
# Processing Record 13 of Set 10 | neepawa
# Processing Record 14 of Set 10 | kununurra
# Processing Record 15 of Set 10 | shirokiy
# Processing Record 16 of Set 10 | whitianga
# Processing Record 17 of Set 10 | novoagansk
# Processing Record 18 of Set 10 | codrington
# Processing Record 19 of Set 10 | dharchula
# Processing Record 20 of Set 10 | presidencia roque saenz pena
# Processing Record 21 of Set 10 | yarmouth
# Processing Record 22 of Set 10 | leshukonskoye
# Processing Record 23 of Set 10 | olafsvik
# Processing Record 24 of Set 10 | houma
# Processing Record 25 of Set 10 | cap malheureux
# Processing Record 26 of Set 10 | morristown
# Processing Record 27 of Set 10 | la asuncion
# Processing Record 28 of Set 10 | koscierzyna
# Processing Record 29 of Set 10 | magadan
# Processing Record 30 of Set 10 | neuquen
# Processing Record 31 of Set 10 | grand gaube
# Processing Record 32 of Set 10 | turukhansk
# Processing Record 33 of Set 10 | hualmay
# Processing Record 34 of Set 10 | smidovich
# Processing Record 35 of Set 10 | port lincoln
# Processing Record 36 of Set 10 | havelock
# Processing Record 37 of Set 10 | burica
# City not found. Skipping...
# Processing Record 38 of Set 10 | taoudenni
# Processing Record 39 of Set 10 | mount gambier
# Processing Record 40 of Set 10 | abashiri
# Processing Record 41 of Set 10 | pousat
# City not found. Skipping...
# Processing Record 42 of Set 10 | kloulklubed
# Processing Record 43 of Set 10 | port hardy
# Processing Record 44 of Set 10 | tikrit
# Processing Record 45 of Set 10 | farafangana
# Processing Record 46 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 47 of Set 10 | klaksvik
# Processing Record 48 of Set 10 | baisha
# Processing Record 49 of Set 10 | colorado
# Processing Record 50 of Set 10 | jalaun
# Processing Record 1 of Set 11 | port-gentil
# Processing Record 2 of Set 11 | cayenne
# Processing Record 3 of Set 11 | teguise
# Processing Record 4 of Set 11 | merritt island
# Processing Record 5 of Set 11 | kaka
# Processing Record 6 of Set 11 | binga
# Processing Record 7 of Set 11 | nandikotkur
# Processing Record 8 of Set 11 | tashtagol
# Processing Record 9 of Set 11 | yazd
# Processing Record 10 of Set 11 | landazuri
# Processing Record 11 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 12 of Set 11 | abengourou
# Processing Record 13 of Set 11 | fort pierce
# Processing Record 14 of Set 11 | jiazi
# Processing Record 15 of Set 11 | leningradskiy
# Processing Record 16 of Set 11 | ayusan
# City not found. Skipping...
# Processing Record 17 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 18 of Set 11 | butembo
# Processing Record 19 of Set 11 | hinganghat
# Processing Record 20 of Set 11 | srednekolymsk
# Processing Record 21 of Set 11 | the pas
# Processing Record 22 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 23 of Set 11 | sarmanovo
# Processing Record 24 of Set 11 | yatou
# Processing Record 25 of Set 11 | deputatskiy
# Processing Record 26 of Set 11 | quang ngai
# Processing Record 27 of Set 11 | robinson
# Processing Record 28 of Set 11 | linjiang
# Processing Record 29 of Set 11 | urengoy
# Processing Record 30 of Set 11 | tupa
# Processing Record 31 of Set 11 | bontang
# Processing Record 32 of Set 11 | liverpool
# Processing Record 33 of Set 11 | sanming
# Processing Record 34 of Set 11 | ossora
# Processing Record 35 of Set 11 | malanje
# Processing Record 36 of Set 11 | conceicao das alagoas
# Processing Record 37 of Set 11 | baijiantan
# Processing Record 38 of Set 11 | kalmunai
# Processing Record 39 of Set 11 | cidreira
# Processing Record 40 of Set 11 | baiyin
# Processing Record 41 of Set 11 | ugoofaaru
# Processing Record 42 of Set 11 | yingzhong
# City not found. Skipping...
# Processing Record 43 of Set 11 | xiongyue
# Processing Record 44 of Set 11 | koumac
# Processing Record 45 of Set 11 | lumberton
# Processing Record 46 of Set 11 | omsukchan
# Processing Record 47 of Set 11 | harper
# Processing Record 48 of Set 11 | walvis bay
# Processing Record 49 of Set 11 | burayevo
# Processing Record 50 of Set 11 | ndele
# Processing Record 1 of Set 12 | rocha
# Processing Record 2 of Set 12 | la mana
# Processing Record 3 of Set 12 | sitka
# Processing Record 4 of Set 12 | igarka
# Processing Record 5 of Set 12 | kangaatsiaq
# Processing Record 6 of Set 12 | hamilton
# Processing Record 7 of Set 12 | hlobyne
# Processing Record 8 of Set 12 | mayo
# Processing Record 9 of Set 12 | ulaangom
# Processing Record 10 of Set 12 | lhokseumawe
# Processing Record 11 of Set 12 | balimo
# City not found. Skipping...
# Processing Record 12 of Set 12 | mnogovershinnyy
# Processing Record 13 of Set 12 | jujuy
# City not found. Skipping...
# Processing Record 14 of Set 12 | belturbet
# Processing Record 15 of Set 12 | moose factory
# Processing Record 16 of Set 12 | kuopio
# Processing Record 17 of Set 12 | sorland
# Processing Record 18 of Set 12 | tuy hoa
# Processing Record 19 of Set 12 | nuuk
# Processing Record 20 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 21 of Set 12 | calvinia
# Processing Record 22 of Set 12 | sao joao da ponte
# Processing Record 23 of Set 12 | kondinskoye
# Processing Record 24 of Set 12 | fevik
# Processing Record 25 of Set 12 | aqtobe
# Processing Record 26 of Set 12 | gap
# Processing Record 27 of Set 12 | manaure
# Processing Record 28 of Set 12 | san rafael
# Processing Record 29 of Set 12 | iskateley
# Processing Record 30 of Set 12 | khakhea
# Processing Record 31 of Set 12 | tambura
# Processing Record 32 of Set 12 | tateyama
# Processing Record 33 of Set 12 | dunedin
# Processing Record 34 of Set 12 | oga
# Processing Record 35 of Set 12 | boundiali
# Processing Record 36 of Set 12 | ahipara
# Processing Record 37 of Set 12 | imbituba
# Processing Record 38 of Set 12 | wamba
# Processing Record 39 of Set 12 | jalu
# Processing Record 40 of Set 12 | kieta
# Processing Record 41 of Set 12 | talcahuano
# Processing Record 42 of Set 12 | taree
# Processing Record 43 of Set 12 | orlik
# Processing Record 44 of Set 12 | abu zabad
# Processing Record 45 of Set 12 | myski
# Processing Record 46 of Set 12 | peleduy
# Processing Record 47 of Set 12 | bairiki
# Processing Record 48 of Set 12 | shelburne
# Processing Record 49 of Set 12 | nome
# Processing Record 50 of Set 12 | tieling
# Processing Record 1 of Set 13 | inirida
# Processing Record 2 of Set 13 | silyanah
# City not found. Skipping...
# Processing Record 3 of Set 13 | ola
# Processing Record 4 of Set 13 | keflavik
# Processing Record 5 of Set 13 | tsaratanana
# Processing Record 6 of Set 13 | nynashamn
# Processing Record 7 of Set 13 | neryungri
# Processing Record 8 of Set 13 | inderborskiy
# City not found. Skipping...
# Processing Record 9 of Set 13 | grootfontein
# Processing Record 10 of Set 13 | key west
# Processing Record 11 of Set 13 | palauig
# Processing Record 12 of Set 13 | bonnyville
# Processing Record 13 of Set 13 | whitehorse
# Processing Record 14 of Set 13 | wetaskiwin
# Processing Record 15 of Set 13 | kungurtug
# Processing Record 16 of Set 13 | along
# Processing Record 17 of Set 13 | beyneu
# Processing Record 18 of Set 13 | bria
# Processing Record 19 of Set 13 | moyo
# Processing Record 20 of Set 13 | kovdor
# Processing Record 21 of Set 13 | pirajui
# Processing Record 22 of Set 13 | shingu
# Processing Record 23 of Set 13 | romanovka
# Processing Record 24 of Set 13 | pangody
# Processing Record 25 of Set 13 | yueyang
# Processing Record 26 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 27 of Set 13 | khilok
# Processing Record 28 of Set 13 | auki
# Processing Record 29 of Set 13 | atambua
# Processing Record 30 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 31 of Set 13 | zorritos
# Processing Record 32 of Set 13 | baykit
# Processing Record 33 of Set 13 | tessalit
# Processing Record 34 of Set 13 | union
# Processing Record 35 of Set 13 | monasterevan
# City not found. Skipping...
# Processing Record 36 of Set 13 | bustonkala
# City not found. Skipping...
# Processing Record 37 of Set 13 | puri
# Processing Record 38 of Set 13 | pembroke
# Processing Record 39 of Set 13 | sur
# Processing Record 40 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 41 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 42 of Set 13 | faridpur
# Processing Record 43 of Set 13 | kabin buri
# Processing Record 44 of Set 13 | tshela
# Processing Record 45 of Set 13 | boditi
# Processing Record 46 of Set 13 | brae
# Processing Record 47 of Set 13 | crossville
# Processing Record 48 of Set 13 | sandakan
# Processing Record 49 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 50 of Set 13 | qunduz
# Processing Record 1 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 14 | salta
# Processing Record 3 of Set 14 | marawi
# Processing Record 4 of Set 14 | sapa
# Processing Record 5 of Set 14 | lesnoy
# Processing Record 6 of Set 14 | belmonte mezzagno
# Processing Record 7 of Set 14 | almenara
# Processing Record 8 of Set 14 | keetmanshoop
# Processing Record 9 of Set 14 | tubuala
# Processing Record 10 of Set 14 | cairns
# Processing Record 11 of Set 14 | oktyabrskoye
# Processing Record 12 of Set 14 | yaan
# Processing Record 13 of Set 14 | tadine
# Processing Record 14 of Set 14 | xining
# Processing Record 15 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 16 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 14 | wanning
# Processing Record 18 of Set 14 | iberia
# Processing Record 19 of Set 14 | tivaouane
# Processing Record 20 of Set 14 | santa cruz
# Processing Record 21 of Set 14 | clarence town
# Processing Record 22 of Set 14 | makubetsu
# Processing Record 23 of Set 14 | vetlanda
# Processing Record 24 of Set 14 | agra
# Processing Record 25 of Set 14 | dondo
# Processing Record 26 of Set 14 | ixtapa
# Processing Record 27 of Set 14 | henties bay
# Processing Record 28 of Set 14 | chapada dos guimaraes
# Processing Record 29 of Set 14 | sistranda
# Processing Record 30 of Set 14 | mabaruma
# Processing Record 31 of Set 14 | birao
# Processing Record 32 of Set 14 | san lorenzo de el escorial
# Processing Record 33 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 34 of Set 14 | venado tuerto
# Processing Record 35 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 36 of Set 14 | sivas
# Processing Record 37 of Set 14 | plouzane
# Processing Record 38 of Set 14 | uribia
# Processing Record 39 of Set 14 | rosario oeste
# Processing Record 40 of Set 14 | ponta delgada
# Processing Record 41 of Set 14 | price
# Processing Record 42 of Set 14 | lagos
# Processing Record 43 of Set 14 | pascagoula
# Processing Record 44 of Set 14 | bani walid
# Processing Record 45 of Set 14 | destin
# Processing Record 46 of Set 14 | wahiawa
# Processing Record 47 of Set 14 | sassandra
# Processing Record 48 of Set 14 | ha giang
# Processing Record 49 of Set 14 | mill valley
# Processing Record 50 of Set 14 | portland
# Processing Record 1 of Set 15 | mugumu
# Processing Record 2 of Set 15 | biak
# Processing Record 3 of Set 15 | owase
# Processing Record 4 of Set 15 | griffith
# Processing Record 5 of Set 15 | bure
# Processing Record 6 of Set 15 | conde
# Processing Record 7 of Set 15 | emba
# Processing Record 8 of Set 15 | leh
# Processing Record 9 of Set 15 | berlevag
# Processing Record 10 of Set 15 | xilitla
# Processing Record 11 of Set 15 | sao joao da barra
# Processing Record 12 of Set 15 | rundu
# Processing Record 13 of Set 15 | tilichiki
# Processing Record 14 of Set 15 | paragominas
# Processing Record 15 of Set 15 | little current
# Processing Record 16 of Set 15 | livanatai
# Processing Record 17 of Set 15 | ambulu
# Processing Record 18 of Set 15 | ferme-neuve
# Processing Record 19 of Set 15 | gazanjyk
# Processing Record 20 of Set 15 | krutinka
# Processing Record 21 of Set 15 | morondava
# Processing Record 22 of Set 15 | naantali
# Processing Record 23 of Set 15 | fukue
# Processing Record 24 of Set 15 | sangueya
# Processing Record 25 of Set 15 | gorodovikovsk
# Processing Record 26 of Set 15 | grand-santi
# Processing Record 27 of Set 15 | bintulu
# Processing Record 28 of Set 15 | lengshuijiang
# Processing Record 29 of Set 15 | buraydah
# Processing Record 30 of Set 15 | winchester
# Processing Record 31 of Set 15 | pangkalanbuun
# Processing Record 32 of Set 15 | hobyo
# Processing Record 33 of Set 15 | ruteng
# Processing Record 34 of Set 15 | vao
# Processing Record 35 of Set 15 | lasa
# Processing Record 36 of Set 15 | karpathos
# Processing Record 37 of Set 15 | svetlyy
# Processing Record 38 of Set 15 | kashi
# Processing Record 39 of Set 15 | takhtamygda
# Processing Record 40 of Set 15 | noumea
# Processing Record 41 of Set 15 | turki
# Processing Record 42 of Set 15 | quesnel
# Processing Record 43 of Set 15 | black river
# Processing Record 44 of Set 15 | vardo
# Processing Record 45 of Set 15 | dawlatabad
# Processing Record 46 of Set 15 | msanga
# Processing Record 47 of Set 15 | marsa matruh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 682

# %% [markdown]
# (Deliverable 1 requirements)
# Lat/lon
# max temp
# humidity
# cloudiness
# wind speed
# description

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %% [markdown]
# deliverable 1 requirements - add to a new dataframe

# %%
# Display sample data
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Lulea  65.5842   22.1547     41.07        81          75        3.44
# 1      Hobart -42.8794  147.3294     40.05        90           1        9.22
# 2        Hofn  64.2539  -15.2082     51.82        71         100       10.36
# 3       Bluff -46.6000  168.3333     37.92        83           7        6.13
# 4     Ushuaia -54.8000  -68.3000     47.86        43           0       16.11
# 5     Rikitea -23.1203 -134.9692     73.53        78          88       15.70
# 6       Roald  62.5833    6.1333     58.12        54           0        8.05
# 7  Carutapera  -1.1950  -46.0200     86.13        61          67       11.81
# 8    La Ronge  55.1001 -105.2842     50.25        71         100       11.50
# 9      Albany  42.6001  -73.9662     60.58        63         100        1.01
#
#   Country                 Date      Current Description
# 0      SE  2022-09-30 17:56:42            broken clouds
# 1      AU  2022-09-30 17:56:36                clear sky
# 2      IS  2022-09-30 17:56:43  light intensity drizzle
# 3      NZ  2022-09-30 17:54:59                clear sky
# 4      AR  2022-09-30 17:53:34                clear sky
# 5      PF  2022-09-30 17:56:44               light rain
# 6      NO  2022-09-30 17:56:44                clear sky
# 7      BR  2022-09-30 17:56:45            broken clouds
# 8      CA  2022-09-30 17:56:45          overcast clouds
# 9      US  2022-09-30 17:56:46          overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Lulea      SE  65.5842   22.1547     41.07        81          75
# 1          Hobart      AU -42.8794  147.3294     40.05        90           1
# 2            Hofn      IS  64.2539  -15.2082     51.82        71         100
# 3           Bluff      NZ -46.6000  168.3333     37.92        83           7
# 4         Ushuaia      AR -54.8000  -68.3000     47.86        43           0
# ..            ...     ...      ...       ...       ...       ...         ...
# 677   Black River      JM  18.0264  -77.8487     82.98        75         100
# 678         Vardo      NO  70.3705   31.1107     42.78        75          75
# 679    Dawlatabad      AF  36.4141   64.9053     71.42        20           2
# 680        Msanga      TZ  -6.0500   36.0333     72.63        52          59
# 681  Marsa Matruh      EG  31.3525   27.2453     81.64        70           0
#
#      Wind Speed      Current Description
# 0          3.44            broken clouds
# 1          9.22                clear sky
# 2         10.36  light intensity drizzle
# 3          6.13                clear sky
# 4         16.11                clear sky
# ..          ...                      ...
# 677        4.79          overcast clouds
# 678       17.27            broken clouds
# 679        4.14                clear sky
# 680        9.86            broken clouds
# 681       10.40                clear sky
#
# [682 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "weather_database/weatherpy_database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %% [markdown]
# deliverable 1 requirement
# export as csv file into weather_database file.
